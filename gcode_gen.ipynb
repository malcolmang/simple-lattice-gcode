# %%
from main import Print
from main import Bounds

# %%
bounds = Bounds((0,0), (60,60))
printobj = Print(bounds, 5, 50, 6, 0.3, 420)
printobj.generate_gcode(print = True)
# Out:
# 'Wrote successfully to gcode/D5H6F420R50.txt!'

# %%
printobj.plot_gif()

# %% [markdown]
# ![test](gif/D1H6F420R50.gif "segment")
